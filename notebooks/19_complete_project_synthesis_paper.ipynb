# %% [markdown]
# # 🌿 Mint Leaf AI — STEP 13: Complete Project Synthesis & Final Research Paper Report
#
# Welcome to **Step 13** of the Mint Leaf AI project (`19_complete_project_synthesis_paper.ipynb`). In this final notebook, we integrate our complete 13-stage experimental validation chain into a publication-ready scientific research paper.
#
# ---
#
# ### 🔬 13-Stage Evidence Chain Synthesis:
# 1. **Dataset Curation & Zero-Leakage Auditing**: 2,086 primary images, 0 exact MD5 duplicates, min dHash distance of 12 bits.
# 2. **Specimen-Aware Partitioning**: 100% group-aware split with zero group overlap.
# 3. **25-Model Benchmark Execution**: Evaluated classical CNNs, lightweight CNNs, modern ConvNeXts, and Vision Transformers.
# 4. **Statistical Robustness & Confidence Intervals**: 95% Wilson Score CIs, 5-Fold Group CV, McNemar chi-square testing.
# 5. **Out-of-Distribution External Generalization**: Evaluated on 349 unseen domain images (0.92% degradation).
# 6. **XAI & Grad-CAM Interpretability**: Confirmed pathological feature alignment over fungal pustules and lesions.
# 7. **Environmental Perturbation Stress-Testing**: Assessed calibration (ECE 0.32%) and blur sensitivity.
# 8. **ONNX & TorchScript Deployment Equivalence**: Verified 100.00% prediction equivalence with 3.45 ms CPU latency.
#
# ---
#
# 📄 **Deliverable**: Complete Research Paper saved under `outputs/reports/final_paper/mint_leaf_ai_research_paper.md`.

# %% [markdown]
# ## 🛠️ Section 1: Complete 13-Stage Experiment Registry Table

# %%
import os
import sys
import json
import time
from pathlib import Path
import numpy as np
import pandas as pd

# Environment Setup
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("🚀 Running in Google Colab ML Laboratory.")
    from google.colab import drive
    drive.mount('/content/drive')
    BASE_PATH = Path('/content/drive/MyDrive/mint-leaf-ai')
else:
    print("💻 Running in Local Antigravity IDE Environment.")
    cwd = Path(os.getcwd()).resolve()
    BASE_PATH = cwd.parent if cwd.name == 'notebooks' else cwd

sys.path.append(str(BASE_PATH))

OUTPUT_PAPER_DIR = BASE_PATH / 'outputs' / 'reports' / 'final_paper'
registry_csv_path = OUTPUT_PAPER_DIR / 'complete_experiment_registry.csv'
df_reg = pd.read_csv(registry_csv_path)

print("📊 Complete 13-Stage Project Experiment Registry:")
display(df_reg)

# %% [markdown]
# ## 📄 Section 2: Summary Paper Metadata & Final Directives

# %%
paper_json_path = OUTPUT_PAPER_DIR / 'mint_leaf_ai_research_paper.json'
with open(paper_json_path, 'r', encoding='utf-8') as f:
    paper_data = json.load(f)

print("=======================================================")
print("MINT LEAF AI RESEARCH PAPER SYNTHESIS SUMMARY")
print("=======================================================")
for k, v in paper_data.items():
    print(f"- {k}: {v}")

print("\n🎉 STEP 13 COMPLETE PROJECT SYNTHESIS FINISHED — PROJECT COMPLETE!")
